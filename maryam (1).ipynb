# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Softmax function
def softmax(x):
    e_x = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e_x / e_x.sum(axis=-1, keepdims=True)

# Self-attention function
def compute_self_attention(sentence):
    tokens = sentence.split()
    n_tokens = len(tokens)
    d_k = 64

    # Random embeddings for demonstration
    np.random.seed(42)
    embeddings = np.random.randn(n_tokens, d_k)

    # Q, K, V
    Q = embeddings
    K = embeddings
    V = embeddings

    # Step 1: Dot product
    scores = np.matmul(Q, K.T)

    # Step 2: Scaling
    scaled_scores = scores / np.sqrt(d_k)

    # Step 3: Softmax
    attention_weights = softmax(scaled_scores)

    return tokens, attention_weights

# Input sentence
sentence = "What are the symptoms of diabetes?"

# Run model
tokens, attention_weights = compute_self_attention(sentence)

# Convert to DataFrame
df_attention = pd.DataFrame(
    attention_weights,
    index=tokens,
    columns=tokens
)

# Print results
print("Self-Attention Weights:")
print(df_attention)

# Plot heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df_attention, annot=True, cmap="viridis", fmt=".2f")

plt.title(f"Self-Attention Heatmap: '{sentence}'")
plt.xlabel("Key Tokens")
plt.ylabel("Query Tokens")

plt.tight_layout()
plt.savefig("attention_heatmap.png")
plt.show()

print("Heatmap saved as attention_heatmap.png")
# Out:
# Self-Attention Weights:
#                What       are       the  symptoms        of  diabetes?
# What       0.985170  0.001505  0.001109  0.000979  0.000534   0.010703
# are        0.000535  0.996682  0.000102  0.000846  0.000165   0.001670
# the        0.000940  0.000242  0.994750  0.000908  0.002434   0.000726
# symptoms   0.000072  0.000176  0.000079  0.999132  0.000516   0.000025
# of         0.000374  0.000326  0.002010  0.004881  0.991429   0.000979
# diabetes?  0.016024  0.007029  0.001283  0.000497  0.002095   0.973072
# Heatmap saved as attention_heatmap.png
